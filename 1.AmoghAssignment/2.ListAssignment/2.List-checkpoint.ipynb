# %% [markdown]
# 1.Create a list of 5 numbers and print it

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %% [markdown]
# 2.Write a program to find the length of a list

# %%
my_list = [1, 2, 3, 4, 5]
print(len(my_list))
# Out:
# 5

# %% [markdown]
# 3.Write a program to add an element to the end of a list

# %%
data = [10,20,30,40,50]
print(data)
# Out:
# [10, 20, 30, 40, 50]

# %%
data[4] = 200
print(data)
# Out:
# [10, 20, 30, 40, 200]

# %% [markdown]
# 4.Write a Program to insert an element at a specific position in a list

# %%
my_list = [10,20,30]
print(my_list)
print(type(my_list))
# Out:
# [10, 20, 30]
# <class 'list'>

# %%
my_list.insert(2,25)
print(my_list)
# Out:
# [10, 20, 25, 30]

# %% [markdown]
# 5.Write a program to remove an element from a list

# %%
nums = [10,20,30,40]
nums.remove(30) # Removes only the second occurrence.
print(nums)
# Out:
# [10, 20, 40]

# %% [markdown]
# 6.Write a program to find the the largest number in a list

# %%
nums = [30,40,50,60]
print(max(nums))
# Out:
# 60

# %% [markdown]
# 7.Write a Program to find the smallest number in a list

# %%
nums = [30,40,50,60]
print(min(nums))
# Out:
# 30

# %% [markdown]
# 8.Write a program to sort a list in ascending order

# %%
nums = [50,20,10,40,30,20,]
print(nums)
# Out:
# [50, 20, 10, 40, 30, 20]

# %%
nums.sort()
print(nums)
# Out:
# [10, 20, 20, 30, 40, 50]

# %% [markdown]
# 9.Write a program to count how many times a specfic element appears in a list

# %%
my_list = [1, 2, 3, 2, 4, 2, 5]
print(my_list)
print(type(my_list))
# Out:
# [1, 2, 3, 2, 4, 2, 5]
# <class 'list'>

# %%
print(my_list.count(2))
# Out:
# 3

# %% [markdown]
# 10.Write a program to reverse a list

# %%
nums = [10,20,30,40,50]
print(nums)
# Out:
# [10, 20, 30, 40, 50]

# %%
nums.reverse()
print(nums)
# Out:
# [50, 40, 30, 20, 10]
