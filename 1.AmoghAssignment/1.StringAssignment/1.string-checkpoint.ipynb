# %% [markdown]
# String Questions(10)
#
# 1.Write a Python Program to print a string entered by the user

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# 2.write a Program to find the length of a string

# %%
str1 = "India"
print(len(str1))
# Out:
# 5

# %% [markdown]
# 3.Write a program to convert a string to uppercase

# %%
s = "python world"
print("Upeercase string:",s.upper())
# Out:
# Upeercase string: PYTHON WORLD

# %% [markdown]
# 4.Write a program to convert a string to lowercase

# %%
s = "HELLO WORLD"
print("lower string:",s.lower())
# Out:
# lower string: hello world

# %% [markdown]
# 5.Write a program to count the number of vowels in a string

# %%
s =("Hello world:")

count = 0
for ch in s:
    count += "aeiouAEIOU".count(ch)

print("Number of vowels:", count)
# Out:
# Number of vowels: 3

# %% [markdown]
# 6.Write a Program to reverse a string

# %%
s = "Hello World"
print(s)
s[::-1]
# Out:
# Hello World
# 'dlroW olleH'

# %% [markdown]
# 7.Write a program to check whether a given string is a palindrome

# %%
s = ("madam")
print(s == s[::-1])
# Out:
# True

# %% [markdown]
# 8.Write a program to Count the occurrence of a specific character in a string

# %%
s = ("Apple")
print(s.count('p'))
# Out:
# 2

# %% [markdown]
# 9.Write a program to repalce a word in a string with anthor word

# %%
s = "Hello World"
text = s.replace("World","Nikki")
print(text)
# Out:
# Hello Nikki

# %% [markdown]
# 10.Write a program to split a sentence into a list of words

# %%
s = ("India:")

t = s.split()

print(t)

print(type(t))
# Out:
# ['India:']
# <class 'list'>
