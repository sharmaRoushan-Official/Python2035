# %% [markdown]
# 6. Write a function display_info(obj) that calls obj.info(). Pass objects of two different classes having an info() method to demonstrate polymorphism.

# %%
class Student:
    def info(self):
        print("I am a Student.")

class Teacher:
    def info(self):
        print("I am a Teacher.")

def display_info(obj):
     obj.info()
        
s = Student()
t = Teacher()

display_info(s)
display_info(t)
# Out:
# I am a Student.
# I am a Teacher.

# %% [markdown]
# 7. Create two classes Dog and Cat with a method sound(). Write a loop that iterates through objects of both classes and calls sound() using polymorphism.

# %%
class Dog:
    def sound(self):
        print("Woof!")

class Cat:
    def sound(self):
        print("Meow!")

animals = [Dog(), Cat()]

for animal in animals:
    animal.sound()
# Out:
# Woof!
# Meow!

# %% [markdown]
# 8. Demonstrate *operator overloading* by overloading the + operator for a class Point(x, y) to add coordinates.

# %%
class Point:
    def __init__(self, x ,y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def display(self):
        print(f"Point({self.x}, {self.y})")

p1 = Point(2,3)
p2 = Point(4,5)

p3 = p1 + p2

p1.display()
p2.display()
p3.display()
# Out:
# Point(2, 3)
# Point(4, 5)
# Point(6, 8)

# %% [markdown]
# 9. Create a class Employee and override its __str__() method to print custom details when the object is printed.

# %%
class Employee:
    def __init__(self, name, employee_id, department):
        self.name = name
        self.employee_id = employee_id
        self.department = department

    def __str__(self):
        return f"Employee ID: {self.employee_id}, Name: {self.name}, Department: {self.department}"


# Creating an Employee object
emp = Employee("Alice", 101, "HR")

# Printing the object
print(emp)
# Out:
# Employee ID: 101, Name: Alice, Department: HR

# %% [markdown]
# 10. Implement method overriding: Parent class Bank has rate_of_interest(). Child classes SBI and HDFC override the method with different interest rates.

# %%
class Bank:
    def rate_of_interest(self):
        return 0

class SBI(Bank):
    def rate_of_interest(self):
        return 6.5

class HDFC(Bank):
    def rate_of_interest(self):
        return 7.0

bank = Bank()
sbi = SBI()
hdfc = HDFC()

print("Bank Interest Rate:", bank.rate_of_interest(), "%")
print("SBI Interest Rate:", sbi.rate_of_interest(), "%")
print("HDFC Interest Rate:", hdfc.rate_of_interest(), "%")
# Out:
# Bank Interest Rate: 0 %
# SBI Interest Rate: 6.5 %
# HDFC Interest Rate: 7.0 %
