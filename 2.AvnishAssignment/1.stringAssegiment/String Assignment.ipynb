# %% [markdown]
# 1. Write a Python program to print a string entered by the user.

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# 2. Write a program to find the length of string.

# %%
str="Hello world"
print (len(str))
# Out:
# 11

# %% [markdown]
# 3. Write a program to convert a string to uppercase.

# %%
s = "Hello world "
print ("Uppercase S:",s.upper())
# Out:
# Uppercase S: HELLO WORLD

# %% [markdown]
# 4. Write a program to convert a string to lowercase.

# %%
s = "Hello world "
print ("Lowercase S:",s.lower())
# Out:
# Lowercase S: hello world

# %% [markdown]
# 5. Write a program to count the number of vowels in a string.

# %%
s=("Hello world on Earth ")

count =0
for ch in s:
    count = "aeiouAEIOU".count (ch)
    print ("Number of vowels:", count)
# Out:
# Number of vowels: 0
# Number of vowels: 1
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 1
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 1
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 1
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 1
# Number of vowels: 1
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 0
# Number of vowels: 0

# %% [markdown]
# 6. Write a program to write reverse a string.

# %%
s="Hello world"
print (s)
s[::-1]
# Out:
# Hello world
# 'dlrow olleH'

# %% [markdown]
# 7. Write a program to check whether a string is a palindrome.

# %%
s=("Hello world")
print (s==s[::-1])
# Out:
# False

# %%
s=("banana")
print(s.count("a"))
# Out:
# 3

# %% [markdown]
# 8.Write a program to replace a word in a string with another world.

# %% [markdown]
# 9.Write a program to count a occurrence of a specific charater in string.

# %%
s = "Hello World on Earth"
text = s.replace("World","Python")
print(text)
# Out:
# Hello Python on Earth

# %%
s = ("Banana")
print (s.count('a'))
# Out:
# 3

# %% [markdown]
# 10.Write a program to split a sentence into a list of words.

# %%
s = ("Hello World:")

t = s.split()

print(t)

print(type(t))
# Out:
# ['Hello', 'World:']
# <class 'list'>
