# %% [markdown]
# 11.Write a Python program to find the largest among three numbers.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))
if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

print("The largest number is:", largest)
# Out:
# Enter first number:  8
# Enter second number:  7
# Enter third number:  9
# The largest number is: 9

# %% [markdown]
# 12.Write a Python program to check whether a number is positive and even, **positive and odd, or **negative.

# %%
num = int(input("Enter a number: "))
if num < 0:
    print("Negative number")
else:
    if num % 2 == 0:
        print("Positive and Even number")
    else:
        print("Positive and Odd number")
# Out:
# Enter a number:  -4
# Negative number

# %% [markdown]
# 13.Write a Python program to check if a number is a single-digit, two-digit, or more than two digits.

# %%
num = int(input("Enter a number: "))
digits = len(str(abs(num)))
if digits == 1:
    print("It is a single-digit number.")
elif digits == 2:
    print("It is a two-digit number.")
else:
    print("It is more than two digits.")
# Out:
# Enter a number:  79
# It is a two-digit number.

# %% [markdown]
# 14.Write a Python program to classify a grade:
#
# A: 90–100
# B: 80–89
# C: 70–79
# D: 60–69
# F: Below 60

# %%
marks =int(input("enter your marks(0-100:"))
if marks >=90 and marks <=100:
    print("Grade A")
elif marks >=80 and marks <=90:
    print("Grade B")
elif marks >=70 and marks <=80:
    print("Grade C")
elif marks >=60 and marks <=70:
    print("Grade D")
elif marks >=0 and marks <=60:
    print("Grade F")
else:
    print("Invaild input! Please enter marks between 0 and 100")
# Out:
# enter your marks(0-100: 92
# Grade A

# %% [markdown]
# 15.Write a Python program to check whether a character is a digit, **uppercase letter, **lowercase letter, or **special character.

# %%
ch = input("Enter a single character: ")
if len(ch) !=1:
    print("Please enter exactly one character.")
else:
    if ch.isdigit():
        print("It is a Digit")
    elif ch.isupper():
        print("It is uppercase letter")
    elif ch.islower():
        print("It Is lowercase letter")
    else:
        print(" It Is special letter")
# Out:
# Enter a single character:  HELLO
# Please enter exactly one character.

# %% [markdown]
# 16.Write a Python program to determine whether a given year is a century year (divisible by 100) or not.

# %%
year = int(input("Enter a year: "))

if year % 100 == 0:
    print(f"{year} is a century year.")
else:
    print(f"{year} is not a century year.")
# Out:
# Enter a year:  5498
# 5498 is not a century year.

# %% [markdown]
# 17.Write a Python program to check whether a triangle is equilateral, **isosceles, or **scalene.

# %%
a = int(input("Enter side 1:"))
b =  int(input("Enter side 2:"))
c =  int(input("Enter side 3:"))
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("it is a equilateral")
    elif a == b or b == c or a == c:
        print("it is a isoseceles")
    else:
        print("it is a scalene")
else:
       print("The given sides do not form a valid triangle.")
# Out:
# Enter side 1: 8
# Enter side 2: 9
# Enter side 3: 5
# it is a scalene

# %% [markdown]
# 18.Write a Python program to check whether the entered password matches the stored password or not.

# %%
stored_password = "mypython@2035"
entered_password = input("Enter a type of your password")
if entered_password == stored_password:
    print("Access granted your password matches")
else:
    print("Access denied Invaild Password")
# Out:
# Enter a type of your password  mypython@2035
# Access denied Invaild Password

# %% [markdown]
# 19.Write a Python program to find whether a given temperature (°C) is cold (<20), **moderate (20–30), or **hot (>30).

# %%
temp = float(input("Enter temperature in °C: "))
if temp < 20:
    print("Cold")
elif 20 <= temp <= 30:
    print("Moderate")
else:
    print("Hot")
# Out:
# Enter temperature in °C:  26
# Moderate

# %% [markdown]
# 20.Write a Python program to check if the entered number is a multiple of 2, 3, both, or none.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0 and num % 3 == 0:
    print("The number is a multiple of both 2 and 3.")
elif num % 2 == 0:
    print("The number is a multiple of 2 only.")
elif num % 3 == 0:
    print("The number is a multiple of 3 only.")
else:
    print("The number is not a multiple of 2 or 3.")
# Out:
# Enter a number:  15
# The number is a multiple of 3 only.
