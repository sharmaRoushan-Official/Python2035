# %% [markdown]
# 21.Write a Python program to calculate discount based on purchase amount:-

# %% [markdown]
# .1000 → 20% discount
# .500–1000 → 10% discount
# .<500 → No discount

# %%
amount = int(input("Enter the purchase amount :"))
if amount > 1000:
    discount = 0.20
elif 500 <= amount <= 1000:
    discount = 0.10
else:
    discount = 0.0
discount_amount = amount * discount
final_price = amount - discount_amount

print("Discount amount:", discount_amount)
print("Final price after discount:", final_price)
# Out:
# Enter the purchase amount : 6896
# Discount amount: 1379.2
# Final price after discount: 5516.8

# %% [markdown]
# 22.Write a Python program to check if a given day number (1–7) corresponds to weekday or weekend.

# %%
day = int(input("Enter The Day Number (1-7): "))
if day>= 1 and day>= 5:
    print("weekday")
elif day == 6 and day == 7:
    print("weekend")
else:
    print("Invaild Day number")
# Out:
# Enter The Day Number (1-7):  4
# Invaild Day number

# %% [markdown]
# 23.Write a Python program to decide the *mode of transport* based on distance:-

# %% [markdown]
# <3 km: Walk
# 3–15 km: Bike
# > 15 km: Car

# %%
num = int(input("Enter distance: "))

if num>15:
    print("Car")
elif num>3 and num<15:
    print("Bike")
else:
    print("Walk")
# Out:
# Enter distance:  45
# Car

# %% [markdown]
# 24.Write a Python program to check if a username starts with a letter and not a number.

# %%
username = input("Enter a username: ")

if username and username[0].youanthe():
    print("Valid username: starts with a letter.")
else:
    print("Invalid username: must start with a letter and not a number.")
# Out:
# Enter a username:  youandthe
# Valid username: starts with a letter.

# %% [markdown]
# 25.Write a Python program to calculate the electricity bill:-
#
# ≤100 units → ₹1 per unit
# 101–200 units → ₹1.5 per unit
# 200 units → ₹2 per unit

# %%
units = int(input("Enter electricity units : "))

if units <= 100:
    bill = units * 5
elif units <= 200:
    bill = (100 * 5) + ((units - 100) * 7)
else:
    bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)

print("Electricity Bill = ₹", bill)
# Out:
# Enter electricity units :  45
# Electricity Bill = ₹ 225

# %% [markdown]
# 26.Write a Python program to determine if a student passed or failed based on marks in three subjects (passing marks = 40).

# %%
sub1 = int(input("Enter marks for subject1: "))
sub2 = int(input("Enter marks for subject2: "))
sub3 = int(input("Enter marks for subject3: "))
if sub1 >=40 and sub2 >=40 and sub3 >=40:
    print("student passed")
else:
    print("student failed")
# Out:
# Enter marks for subject1:  57
# Enter marks for subject2:  99
# Enter marks for subject3:  89
# student passed

# %% [markdown]
# 27.Write a Python program to check whether a given year is a leap century year (divisible by both 100 and 400).

# %%
year = int(input("Enter a year"))
if year % 100 == 0 and year % 400 == 0:
    print(year,"is a leap centuery year:")
else:
    print(year,"is not a leap centuery year:")
# Out:
# Enter a year 2968
# 2968 is not a leap centuery year:

# %% [markdown]
# 28.Write a Python program to check whether a bank account balance is low (<1000), **medium (1000–5000), or **high (>5000).

# %%
balance = int(input("Enter account balance: "))

# Check balance category
if balance < 1000:
    print("Low Balance")
elif 1000 <= balance <= 5000:
    print("Medium Balance")
else:
    print("High Balance")
# Out:
# Enter account balance:  100000
# High Balance

# %% [markdown]
# 29.Write a Python program to classify BMI (Body Mass Index):
#
# <18.5 → Underweight
# 18.5–24.9 → Normal
# 25–29.9 → Overweight
# ≥30 → Obese

# %%
weight = float(input("Enter weight in kg: "))
height = float(input("Enter height in meters: "))

bmi = weight / (height**2)

print("Your BMI is:", round(bmi, 2))

if bmi < 18.5:
    print("Category: Underweight")
elif 18.5 <= bmi <= 24.9:
   print("Category: Normal")
elif 25 <= bmi <= 29.9:
    print("Category: Overweight")
else:
    print("Category: Obese")
# Out:
# Enter weight in kg:  43
# Enter height in meters:  165
# Your BMI is: 0.0
# Category: Underweight

# %% [markdown]
# 30.Write a Python program to check whether an input string is empty, **only spaces, or **contains characters.

# %%
def check_string(s):
    if s == "":
        return "Empty string"
    elif s.isspace():
        return "Only spaces"
    else:
        return "Contains characters"
user_input = input("Enter a string: ")


result = check_string(user_input)
print("Result:", result)
# Out:
# Enter a string:  76
# Result: Contains characters
