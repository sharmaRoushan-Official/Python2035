# %% [markdown]
# 1.Create a tuple containing 5 different values and print it.

# %%
data = ('Jhon',20,78.9,True,'A+')
print(data)
print(type(data))
# Out:
# ('Jhon', 20, 78.9, True, 'A+')
# <class 'tuple'>

# %% [markdown]
# 2.Write a program to find the length of a tuple.

# %%
numbers = (10,20,30,40,50,60)
print(len(numbers))
# Out:
# 6

# %% [markdown]
# 3.Write a program to assess the third element of a tuple.

# %%
numbers = (10,20,30,40,50,60,70)
print(numbers)
print(type(numbers))
# Out:
# (10, 20, 30, 40, 50, 60, 70)
# <class 'tuple'>

# %%
print("third elemet",numbers[3])
# Out:
# third elemet 40

# %% [markdown]
# 4.Write a program to check whether an element exists in a tuple.

# %%
t = (10,20,30,40,50,60,70)
print(t)
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
print(60 in t)
# Out:
# True

# %% [markdown]
# 5.Write a program to count the occurrence of a specific value in a tuple.

# %%
t = (10,20,60,70,60,50,60,40,48,60)
print(t.count(60))
# Out:
# 4

# %% [markdown]
# 6.Write a Program to find the index of a given element in a tuple.

# %%
num = (10,20,30,40,50,60,70)
print(num)
print(type(num))
# Out:
# (10, 20, 30, 40, 50, 60, 70)
# <class 'tuple'>

# %%
print(numbers.index(10))
print(numbers.index(20))
print(numbers.index(30))
print(numbers.index(40))
print(numbers.index(50))
print(numbers.index(60))
print(numbers.index(70))
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# 7.Write a program to concatenate two tuples.

# %%
t1 = (1,2,3)
t2 = (4,5,6)
result = t1 + t2
print(result)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# 8.Write a program to convert a tuple into a list.

# %%
t = (10,20,30,40,50,60)
print(t)
print(type(t))
# Out:
# (10, 20, 30, 40, 50, 60)
# <class 'tuple'>

# %%
t = list(t)
print(t)
print(type(t))
# Out:
# [10, 20, 30, 40, 50, 60]
# <class 'list'>

# %% [markdown]
# 9.Write a program to find the maximum and minmum values in a tuple.

# %%
num = (10,20,30,40,50,60)
print(max(num))
print(min(num))
# Out:
# 60
# 10

# %% [markdown]
# 10.Write a program to iterate through all elements of a tuple and print them.

# %%
t = (10,20,30,40,50,60)
print(num)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
for item in t:
   print(t)
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60)
