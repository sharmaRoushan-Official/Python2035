# %% [markdown]
# 1.Create a list of 5 numbers and print it.

# %%
list = [1, 2, 3, 4, 5]
print(list)
print(type(list))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %% [markdown]
# 2.Write a program to find the length of a list.

# %%
list = [1, 2, 3, 4, 5]
print(len(list))
# Out:
# 5

# %% [markdown]
# 3.Write a program to add an element to the end of a list.

# %%
list = [10,20,30,40,50]
print(list)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# 4.Write a Program to insert an element at a specific position in a list.

# %%
list = [10,20,30]
print(list)
print(type(list))
# Out:
# [10, 20, 30]
# <class 'list'>

# %% [markdown]
# 5.Write a program to remove an element from a list.

# %%
nums = [10,20,30,40]
nums.remove(30) 
print(nums)
# Out:
# [10, 20, 40]

# %% [markdown]
# 6.Write a program to find the the largest number in a list.

# %%
nums = [100,40,80,67,87]
print(max(nums))
# Out:
# 100

# %% [markdown]
# 7.Write a Program to find the smallest number in a list.

# %%
nums = [100,40,67,80,97,27]
print(min(nums))
# Out:
# 27

# %% [markdown]
# 8.Write a program to sort a list in ascending order.

# %%
nums = [52,24,36,46,67,28,60]
print(nums)
# Out:
# [52, 24, 36, 46, 67, 28, 60]

# %%
nums.sort()
print(nums)
# Out:
# [24, 28, 36, 46, 52, 60, 67]

# %% [markdown]
# 9.Write a program to count how many times a specfic element appears in a list.

# %%
list = [1, 2, 3, 2, 4, 2,3,5,7,9,1,5]
print(list)
print(type(list))
# Out:
# [1, 2, 3, 2, 4, 2, 3, 5, 7, 9, 1, 5]
# <class 'list'>

# %%
print(list.count(2))
# Out:
# 3

# %% [markdown]
# 10.Write a program to reverse a list.

# %%
nums = [10,20,30,40,50,60,70,80]
print(nums)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
nums.reverse()
print(nums)
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]
