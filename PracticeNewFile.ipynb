# %% [markdown]
# # Python Practice Questions
#
# ## 1. Condition — 10 Questions
#
# 1. Write a Python program to check whether a number is **positive, negative, or zero**.
# 2. Write a program to check whether a number is **even or odd**.
# 3. Write a program to find the **largest of two numbers**.
# 4. Write a program to find the **largest of three numbers** using `if-elif-else`.
# 5. Write a program to check whether a given year is a **leap year**.
# 6. Write a program to check whether a person is **eligible to vote** based on age.
# 7. Write a program to calculate grades based on marks:
#
#    * 90–100 → A
#    * 75–89 → B
#    * 60–74 → C
#    * 40–59 → D
#    * Below 40 → Fail
# 8. Write a program to check whether a character is a **vowel or consonant**.
# 9. Write a program to check whether three given sides can form a **valid triangle**.
# 10. Write a program to create a **simple calculator** using `if-elif` for `+`, `-`, `*`, `/`.
#
# ---
#
# ## 2. For Loop — 10 Questions
#
# 1. Print numbers from **1 to 10** using a `for` loop.
# 2. Print all **even numbers from 1 to 50**.
# 3. Print all **odd numbers from 1 to 50**.
# 4. Print the **multiplication table** of a given number.
# 5. Find the **sum of numbers from 1 to n**.
# 6. Find the **factorial of a number** using a `for` loop.
# 7. Count the number of **digits in a number** using a loop.
# 8. Reverse a number using a `for` loop.
# 9. Print the following pattern:
#
# ```text
# *
# **
# ***
# ****
# *****
# ```
#
# 10. Print the following pattern:
#
# ```text
# 1
# 12
# 123
# 1234
# 12345
# ```
#
# ---
#
# ## 3. While Loop — 10 Questions
#
# 1. Print numbers from **1 to 10** using a `while` loop.
# 2. Print numbers from **10 to 1** using a `while` loop.
# 3. Print all **even numbers from 1 to 100**.
# 4. Find the **sum of digits** of a number.
# 5. Reverse a given number.
# 6. Check whether a number is a **palindrome**.
# 7. Find the **factorial** of a number using `while`.
# 8. Count the number of digits in a number.
# 9. Keep accepting numbers from the user until the user enters **0**, then display their sum.
# 10. Create a number guessing program where the user keeps guessing until they guess the correct number.
#
# ---
#
# ## 4. Functions — 10 Questions
#
# 1. Create a function `greet()` that prints `"Hello Python"`.
# 2. Create a function that accepts a name and prints a greeting.
# 3. Create a function that accepts two numbers and returns their **sum**.
# 4. Create a function to check whether a number is **even or odd**.
# 5. Create a function to find the **largest of three numbers**.
# 6. Create a function to calculate the **factorial** of a number.
# 7. Create a function to check whether a number is **prime**.
# 8. Create a function to calculate the **area of a circle**.
# 9. Create a function that accepts a list and returns the **maximum and minimum** values.
# 10. Create a function that accepts a string and returns the **number of vowels** in it.
#
# ---
#
# ## 5. OOP – Inheritance — 10 Questions
#
# 1. Create a `Person` class and inherit it into a `Student` class.
# 2. Create an `Animal` class with a `speak()` method and inherit it into `Dog`.
# 3. Create a `Vehicle` class and inherit it into `Car`.
# 4. Demonstrate **single inheritance** using `Employee` and `Manager`.
# 5. Demonstrate **multilevel inheritance**:
#
# ```text
# Grandfather → Father → Son
# ```
#
# 6. Demonstrate **multiple inheritance** using two parent classes.
# 7. Create `Shape → Rectangle → Square` to demonstrate multilevel inheritance.
# 8. Create `Employee` with `name` and `salary`, then create `Developer` with an additional `language` attribute.
# 9. Create a `BankAccount` parent class and `SavingsAccount` child class.
# 10. Create a program demonstrating the difference between **single, multilevel, and multiple inheritance**.
#
# ---
#
# ## 6. Polymorphism — 10 Questions
#
# 1. Create `Dog` and `Cat` classes with the same `sound()` method but different outputs.
#
# 2. Demonstrate polymorphism using `Animal`, `Dog`, and `Cat`.
#
# 3. Create `Car`, `Bike`, and `Bus` classes with a common `start()` method.
#
# 4. Create different payment classes:
#
#    * `UPI`
#    * `CreditCard`
#    * `Cash`
#
#    Each should have a `pay()` method.
#
# 5. Create `Shape`, `Circle`, and `Rectangle` classes with a common `area()` method.
#
# 6. Demonstrate **method overriding** using parent and child classes.
#
# 7. Create `Employee`, `Developer`, and `Manager` classes with a common `work()` method.
#
# 8. Create a function that accepts different objects and calls their common method.
#
# 9. Demonstrate polymorphism using a list containing objects of different classes.
#
# 10. Create a simple **notification system** where `Email`, `SMS`, and `WhatsApp` have a common `send()` method.
#
# ---
#
# ## 7. Encapsulation — 10 Questions
#
# 1. Create a `BankAccount` class with a private `__balance` variable.
# 2. Create getter and setter methods for a student's marks.
# 3. Create a `Student` class where age cannot be accessed directly.
# 4. Create a `Person` class with private `__name` and methods to access it.
# 5. Create a bank account where the balance can only be changed through `deposit()` and `withdraw()`.
# 6. Prevent a user from setting a **negative salary** using encapsulation.
# 7. Create a `Password` class where the password is stored privately.
# 8. Create a `Product` class with a private price and validate that price cannot be negative.
# 9. Demonstrate the use of Python's **name mangling** with `__variable`.
# 10. Create an ATM class where account balance and PIN are encapsulated.
#
# ---
#
# ## 8. Data Abstraction — 10 Questions
#
# Use Python's `abc` module where appropriate.
#
# 1. Create an abstract `Animal` class with an abstract `sound()` method.
# 2. Create an abstract `Shape` class with an abstract `area()` method.
# 3. Implement `Circle` and `Rectangle` using the `Shape` abstract class.
# 4. Create an abstract `Vehicle` class with `start()` and implement it in `Car`.
# 5. Create an abstract `Payment` class with `pay()` and implement:
#
#    * `UPI`
#    * `Card`
#    * `Cash`
# 6. Create an abstract `Employee` class with a `calculate_salary()` method.
# 7. Create an abstract `Database` class with `connect()` and implement `MySQLDatabase` and `SQLiteDatabase`.
# 8. Create an abstract `Notification` class with `send()` and implement `EmailNotification` and `SMSNotification`.
# 9. Demonstrate why an **abstract class cannot normally be instantiated**.
# 10. Build a small **banking system** using abstraction with `Account`, `SavingsAccount`, and `CurrentAccount`.
#
# ---
#
# ## 9. File Handling — 10 Questions
#
# 1. Create a text file and write `"Hello Python"` into it.
# 2. Read and display the contents of a text file.
# 3. Append a new line to an existing file.
# 4. Count the **number of lines** in a file.
# 5. Count the **number of words** in a file.
# 6. Count the **number of characters** in a file.
# 7. Read a file and display only the lines containing the word `"Python"`.
# 8. Copy the contents of one file into another file.
# 9. Read a file and find the **most frequently occurring word**.
# 10. Create a student file containing:
#
# ```text
# Roushan,80
# Rahul,75
# Amit,90
# ```
#
# Read the file and display the student with the **highest marks**.
#
# ---
#
# ## 10. List Comprehension — 10 Questions
#
# 1. Create a list containing numbers from **1 to 10** using list comprehension.
# 2. Create a list containing squares of numbers from **1 to 10**.
# 3. Create a list containing only **even numbers** from 1 to 50.
# 4. Create a list containing only **odd numbers** from 1 to 50.
# 5. Convert the following list to uppercase:
#
# ```python
# names = ["roushan", "rahul", "amit"]
# ```
#
# 6. Extract numbers greater than 50:
#
# ```python
# numbers = [10, 55, 20, 80, 45, 90]
# ```
#
# 7. Create a list of the **lengths of each word**:
#
# ```python
# words = ["Python", "Java", "Django", "SQL"]
# ```
#
# 8. Create a list containing the **first letter** of every word.
# 9. Replace negative numbers with `0` using list comprehension.
# 10. Create a list of numbers from 1–100 that are divisible by **3 and 5**.
#
# ---
#
# ## 11. Generator — 10 Questions
#
# 1. Create a generator that produces numbers from **1 to 10**.
# 2. Create a generator that produces all **even numbers from 1 to 50**.
# 3. Create a generator for **square numbers**.
# 4. Create a generator that produces numbers from `n` down to `1`.
# 5. Create a generator that produces the **Fibonacci sequence**.
# 6. Create a generator that produces the first **10 prime numbers**.
# 7. Create a generator that reads a file **line by line**.
# 8. Create a generator that yields each character of a string one at a time.
# 9. Create a generator that yields numbers divisible by **5**.
# 10. Demonstrate the difference between a **normal function returning a list** and a **generator function using `yield`**.
#
# ---
#
# ## 12. JSON — 10 Questions
#
# 1. Create a Python dictionary containing student information and convert it into a **JSON string** using `json.dumps()`.
# 2. Convert the following JSON string into a Python dictionary using `json.loads()`:
#
# ```python
# '{"name": "Roushan", "age": 26, "course": "Python"}'
# ```
#
# 3. Write student data into a JSON file using `json.dump()`.
# 4. Read data from a JSON file using `json.load()`.
# 5. Create a JSON file containing information about **5 students**.
# 6. Read the student JSON file and display students having marks greater than **80**.
# 7. Update a student's marks in a JSON file.
# 8. Add a new student to an existing JSON file.
# 9. Delete a student from a JSON file based on their ID.
# 10. Create a **Student Management System using JSON** with operations:
#
# ```text
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
#
#
#
# ```
#
# # File Handling in Python
#
# ## 13. Reading Files — 10 Questions
#
# 1. Create a text file named `data.txt` and read its complete contents using `read()`.
#
# 2. Read a file line by line using `readline()`.
#
# 3. Read all lines of a file using `readlines()` and display them one by one.
#
# 4. Count the **number of lines** present in a text file.
#
# 5. Count the **number of words** present in a text file.
#
# 6. Count the **number of characters** present in a text file.
#
# 7. Read a file and display only the lines that contain the word **`Python`**.
#
# 8. Read a file and count how many times the word **`Python`** occurs.
#
# 9. Read a file containing numbers, such as:
#
# ```text
# 10
# 20
# 30
# 40
# 50
# ```
#
# Find and display the **sum and average** of all numbers.
#
# 10. Read a student file containing:
#
# ```text
# Roushan,80
# Rahul,75
# Amit,90
# Neha,85
# ```
#
# Read the file and display the student who has the **highest marks**.
#
# ---
#
# ## 14. Writing Files — 10 Questions
#
# 1. Create a file named `data.txt` and write `"Hello Python"` into it using `write()`.
#
# 2. Write multiple lines into a file using `write()`.
#
# 3. Write a list of strings into a file using `writelines()`.
#
# 4. Take a user's **name, age, and city** as input and write the information into a file.
#
# 5. Write numbers from **1 to 10** into a file, with each number on a separate line.
#
# 6. Take 5 student names from the user and write them into a file.
#
# 7. Take 5 numbers from the user and write them into a file. Then calculate and store their **sum** in the same file.
#
# 8. Create a student file containing:
#
# ```text
# Roushan,80
# Rahul,75
# Amit,90
# Neha,85
# ```
#
# Write the data into the file using Python.
#
# 9. Create a program that accepts a paragraph from the user and writes it into `paragraph.txt`.
#
# 10. Create a program that takes student details:
#
# ```text
# ID
# Name
# Age
# Course
# Marks
# ```
#
# and writes the details of **5 students** into a text file.
#
# ---
#
# # File Modes to Practice
#
# ```text
# r   → Read
# w   → Write
# a   → Append
# r+  → Read + Write
# w+  → Write + Read
# a+  → Append + Read
# ```
#
# # Important File Methods
#
# ```python
# open()
# read()
# readline()
# readlines()
# write()
# writelines()
# close()
# ```
#
# # Recommended Practice
#
# ```text
# Reading Files
#      ↓
# Writing Files
#      ↓
# Appending Files
#      ↓
# Reading + Writing
#      ↓
# File Processing
#      ↓
# CSV
#      ↓
# JSON
# ```
#
#
# ---
#
# # Practice Order
#
# ```text
# Condition
#     ↓
# For Loop
#     ↓
# While Loop
#     ↓
# Functions
#     ↓
# List Comprehension
#     ↓
# File Handling
#     ↓
# JSON
#     ↓
# OOP
#     ↓
# Inheritance
#     ↓
# Polymorphism
#     ↓
# Encapsulation
#     ↓
# Data Abstraction
#     ↓
# Generators
# ```
#
# # Total Questions
#
# ```text
# Condition          → 10
# For Loop           → 10
# While Loop         → 10
# Functions          → 10
# Inheritance        → 10
# Polymorphism       → 10
# Encapsulation      → 10
# Data Abstraction   → 10
# File Handling      → 10
# List Comprehension → 10
# Generator          → 10
# JSON               → 10
# --------------------------------
# Total              → 120 Questions
# ```
